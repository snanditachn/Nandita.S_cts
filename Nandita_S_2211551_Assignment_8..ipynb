# %%
# !pip install opencv-python
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2
from matplotlib import pyplot
# %matplotlib inline
# Out:
# Requirement already satisfied: opencv-python in c:\users\2211551\anacondaf\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5; python_version >= "3.7" in c:\users\2211551\anacondaf\lib\site-packages (from opencv-python) (1.18.1)

# %%
image_color = mpimg.imread("hiway.jpg")

# %%
plt.imshow(image_color)

# %%
image_color.shape
# Out:
# (1205, 1805, 3)

# %%
image_gray = cv2.cvtColor(image_color,cv2.COLOR_BGR2GRAY)

plt.imshow(image_gray,cmap='gray');

# %%
image_gray.shape
# Out:
# (1205, 1805)

# %%
image_copy = np.copy(image_gray)
image_copy.shape
# Out:
# (1205, 1805)

# %%
image_copy[(image_copy[:,:]<150)]=0

# %%
plt.imshow(image_copy,cmap='gray')
plt.show()

# %%
image_copy = np.copy(image_color)
image_copy.shape
# Out:
# (1205, 1805, 3)

# %% [markdown]
# BGR
#
# image_copy[:,:,0] < 200 = blue
# image_copy[:,:,1] < 200 = Green
# image_copy[:,:,2] < 200 = Red

# %%
image_copy[ (image_copy[:,:,0] < 90) | (image_copy[:,:,1] < 90) |
           (image_copy[:,:,2] < 90) ] = 0  # any value that is not white

# %%
plt.imshow(image_copy,cmap='gray')
plt.show()

# %% [markdown]
# # Region of interest

# %%
height,width,channels = image_color.shape
channels
# Out:
# 3

# %%
height,width = image_color.shape[:2]
height
# Out:
# 1205

# %%
width
# Out:
# 1805

# %% [markdown]
# PERFORM REGION OF INTEREST MASKING

# %%
# Select points of the region of interest (ROI)
ROI = np.array([[(0,height),(0, 800),(1250, 750), (1500, 750), (width, 900), (width,height)]], dtype=np.int32)    
 
# define a blank image with all zeros (ie: black) 
blank = np.zeros_like(image_gray)

# %%
# Fill the Region of interest with white color (ie: 255)!

mask = cv2.fillPoly(blank, ROI, 255)

# %%
# Perform bitwise AND operation to select only the region of interest

masked_image = cv2.bitwise_and(image_gray, mask)

# %%
masked_image.shape
# Out:
# (1205, 1805)

# %%
plt.imshow(masked_image, cmap = 'gray');
