# %% [markdown]
# <a href="https://colab.research.google.com/github/snanditachn/Nandita.S_cts/blob/main/12_9_ex_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b01c41b1-f2d7-48b8-8991-80b161c9e21d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b01c41b1-f2d7-48b8-8991-80b161c9e21d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving chn.csv to chn.csv

# %%
import pandas as pd
import io
 
chn= pd.read_csv(io.BytesIO(uploaded['chn.csv']))
chn.head(5)
# Out:
#          time  tavg  tmin  tmax  prcp
# 0  01-01-1990  25.2  22.8  28.4   0.5
# 1  02-01-1990  24.9  21.7  29.1   0.0
# 2  03-01-1990  25.6  21.4  29.8   0.0
# 3  04-01-1990  25.7   NaN  28.7   0.0
# 4  05-01-1990  25.5  20.7  28.4   0.0

# %%
chn.describe()
# Out:
#                tavg         tmin          tmax         prcp
# count  11867.000000  8810.000000  10875.000000  7008.000000
# mean      28.490798    24.382770     33.908285     6.244378
# std        2.605824     2.592423      3.380630    19.039751
# min       20.900000    12.000000     23.800000     0.000000
# 25%       26.300000    22.600000     31.100000     0.000000
# 50%       28.700000    24.600000     34.000000     0.000000
# 75%       30.400000    26.400000     36.200000     3.000000
# max       36.600000    31.000000     44.600000   344.900000

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
freq = pd.crosstab(index=chn['tavg'],columns='Frequency')
freq
# Out:
# col_0  Frequency
# tavg
# 20.9           1
# 21.4           2
# 21.6           1
# 21.7           2
# 22.1           2
# ...          ...
# 35.4           1
# 35.6           3
# 35.8           1
# 35.9           1
# 36.6           2
#
# [141 rows x 1 columns]

# %%
sns.histplot(x='tavg',data=chn)

# %%
freq = pd.crosstab(index=chn['tmin'],columns='Frequency')
freq
# Out:
# col_0  Frequency
# tmin
# 12.0           1
# 16.9           2
# 17.0           3
# 17.1           1
# 17.2           3
# ...          ...
# 30.4           2
# 30.6           1
# 30.8           1
# 30.9           1
# 31.0           2
#
# [140 rows x 1 columns]

# %%
sns.histplot(x='tmin',data=chn)

# %%
freq = pd.crosstab(index=chn['tmax'],columns='Frequency')
freq
# Out:
# col_0  Frequency
# tmax
# 23.8           1
# 24.0           2
# 24.1           1
# 24.2           3
# 24.3           1
# ...          ...
# 43.8           1
# 44.1           1
# 44.2           1
# 44.3           1
# 44.6           1
#
# [201 rows x 1 columns]

# %%
sns.histplot(x='tmax',data=chn)

# %%
freq = pd.crosstab(index=chn['prcp'],columns='Frequency')
freq
# Out:
# col_0  Frequency
# prcp
# 0.0         4149
# 0.1           24
# 0.2           19
# 0.3          222
# 0.4           12
# ...          ...
# 264.9          1
# 268.5          1
# 278.9          1
# 283.0          1
# 344.9          1
#
# [337 rows x 1 columns]

# %%
sns.histplot(x='prcp',data=chn)
